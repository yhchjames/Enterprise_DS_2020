# %%
import pandas as pd
import numpy as np

from datetime import datetime

# %%
data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path) # pd_raw is Dataframe,

# %%
pd_raw.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/4/20  5/5/20  5/6/20  5/7/20  5/8/20  \
# 0        0        0        0  ...    2894    3224    3392    3563    3778
# 1        0        0        0  ...     803     820     832     842     850
# 2        0        0        0  ...    4648    4838    4997    5182    5369
# 3        0        0        0  ...     750     751     751     752     752
# 4        0        0        0  ...      35      36      36      36      43
#
#    5/9/20  5/10/20  5/11/20  5/12/20  5/13/20
# ...

# %%
time_idx = pd_raw.columns[4:]
print(time_idx)
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '5/4/20', '5/5/20', '5/6/20', '5/7/20', '5/8/20', '5/9/20', '5/10/20',
#        '5/11/20', '5/12/20', '5/13/20'],
#       dtype='object', length=113)

# %%
df_plot = pd.DataFrame({'date':time_idx})
df_plot.head()
# Out:
#       date
# 0  1/22/20
# 1  1/23/20
# 2  1/24/20
# 3  1/25/20
# 4  1/26/20

# %%
pd_raw['Country/Region']
# Out:
# 0                Afghanistan
# 1                    Albania
# 2                    Algeria
# 3                    Andorra
# 4                     Angola
#                ...
# 262    Sao Tome and Principe
# 263                    Yemen
# 264                  Comoros
# 265               Tajikistan
# 266                  Lesotho
# Name: Country/Region, Length: 267, dtype: object

# %%
pd_raw[pd_raw['Country/Region']=='Germany'].iloc[:,4::].sum(axis=0)#return a panda series, we have to make it a array
# Out:
# 1/22/20         0
# 1/23/20         0
# 1/24/20         0
# 1/25/20         0
# 1/26/20         0
#             ...
# 5/9/20     171324
# 5/10/20    171879
# 5/11/20    172576
# 5/12/20    173171
# 5/13/20    174098
# Length: 113, dtype: int64

# %%
country_list=['Italy',
              'US',
              'Spain',
              'Germany',
             'Taiwan*'
             ]

# %%
for each in country_list:
    df_plot[each]=np.array(pd_raw[pd_raw['Country/Region']==each].iloc[:,4::].sum(axis=0))

# %%
# %matplotlib inline
df_plot.set_index('date').plot() # make 'date' as index and plot it, dataframe is easier to plot

# %%
datetime.strptime(df_plot['date'][0],"%m/%d/%y")
# Out:
# datetime.datetime(2020, 1, 22, 0, 0)

# %%
time_idx = [datetime.strptime(i,"%m/%d/%y") for i in df_plot['date']] #from string to dateform
time_idx
# Out:
# [datetime.datetime(2020, 1, 22, 0, 0),
#  datetime.datetime(2020, 1, 23, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2020, 1, 25, 0, 0),
#  datetime.datetime(2020, 1, 26, 0, 0),
#  datetime.datetime(2020, 1, 27, 0, 0),
#  datetime.datetime(2020, 1, 28, 0, 0),
#  datetime.datetime(2020, 1, 29, 0, 0),
#  datetime.datetime(2020, 1, 30, 0, 0),
#  datetime.datetime(2020, 1, 31, 0, 0),
#  datetime.datetime(2020, 2, 1, 0, 0),
#  datetime.datetime(2020, 2, 2, 0, 0),
#  datetime.datetime(2020, 2, 3, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2020, 2, 5, 0, 0),
#  datetime.datetime(2020, 2, 6, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2020, 2, 8, 0, 0),
#  datetime.datetime(2020, 2, 9, 0, 0),
#  datetime.datetime(2020, 2, 10, 0, 0),
#  datetime.datetime(2020, 2, 11, 0, 0),
#  datetime.datetime(2020, 2, 12, 0, 0),
#  datetime.datetime(2020, 2, 13, 0, 0),
#  datetime.datetime(2020, 2, 14, 0, 0),
# ...

# %%
time_str = [i.strftime('%Y-%m-%d') for i in time_idx] # dateform to strings
time_str
# Out:
# ['2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-02',
#  '2020-03-03',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-06',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-11',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
#  '2020-03-18',
#  '2020-03-19',
# ...

# %%
df_plot['date']=time_idx

# %%
df_plot.head()
# Out:
#         date  Italy  US  Spain  Germany  Taiwan*
# 0 2020-01-22      0   1      0        0        1
# 1 2020-01-23      0   1      0        0        1
# 2 2020-01-24      0   2      0        0        3
# 3 2020-01-25      0   2      0        0        3
# 4 2020-01-26      0   5      0        0        4

# %%
df_plot.to_csv('../data/processed/COVID_small_flat_table.csv',sep=';',index=False)

# %% [markdown]
# ## Relational data model - defining a primary key

# %%
data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)
pd_raw.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/4/20  5/5/20  5/6/20  5/7/20  5/8/20  \
# 0        0        0        0  ...    2894    3224    3392    3563    3778
# 1        0        0        0  ...     803     820     832     842     850
# 2        0        0        0  ...    4648    4838    4997    5182    5369
# 3        0        0        0  ...     750     751     751     752     752
# 4        0        0        0  ...      35      36      36      36      43
#
#    5/9/20  5/10/20  5/11/20  5/12/20  5/13/20
# ...

# %%
pd_data_base=pd_raw.rename(columns={'Country/Region':'country',
                      'Province/State':'state'})
pd_data_base['state']=pd_data_base['state'].fillna('no')  #ensure a sring, important for indexing

# %%
pd_data_base=pd_data_base.drop(['Lat','Long'],axis=1)
pd_data_base.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    no  Afghanistan        0        0        0        0        0        0
# 1    no      Albania        0        0        0        0        0        0
# 2    no      Algeria        0        0        0        0        0        0
# 3    no      Andorra        0        0        0        0        0        0
# 4    no       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  5/4/20  5/5/20  5/6/20  5/7/20  5/8/20  5/9/20  \
# 0        0        0  ...    2894    3224    3392    3563    3778    4033
# 1        0        0  ...     803     820     832     842     850     856
# 2        0        0  ...    4648    4838    4997    5182    5369    5558
# 3        0        0  ...     750     751     751     752     752     754
# 4        0        0  ...      35      36      36      36      43      43
#
#    5/10/20  5/11/20  5/12/20  5/13/20
# ...

# %%
pd_relational_model=pd_data_base.set_index(['state','country']) \
                                .T                              \
                                .stack(level=[0,1])             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model.head()
# Out:
#       date                         state         country  confirmed
# 0  1/22/20                       Alberta          Canada        0.0
# 1  1/22/20                      Anguilla  United Kingdom        0.0
# 2  1/22/20                         Anhui           China        1.0
# 3  1/22/20                         Aruba     Netherlands        0.0
# 4  1/22/20  Australian Capital Territory       Australia        0.0

# %%
pd_relational_model['date']=pd_relational_model.date.astype('datetime64[ns]') # it can transform to date directly

# %%
pd_relational_model.confirmed=pd_relational_model.confirmed.astype(int) # float to int

pd_relational_model.to_csv('../data/processed/COVID_relational_confirmed.csv',sep=';',index=False)

# %%
pd_relational_model.dtypes
# Out:
# date         datetime64[ns]
# state                object
# country              object
# confirmed             int64
# dtype: object

# %%
data_path='../data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
pd_raw_US=pd.read_csv(data_path)
pd_raw_US.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_  ... 5/4/20  5/5/20  5/6/20  5/7/20  5/8/20  5/9/20  \
# 0 -14.2710 -170.1320  ...      0       0       0       0       0       0
# 1  13.4443  144.7937  ...    145     145     149     149     151     151
# 2  15.0979  145.6739  ...     14      14      15      15      15      16
# 3  18.2208  -66.5901  ...   1843    1924    1968    2031    2156    2173
# 4  18.3358  -64.8963  ...     66      66      66      66      68      68
#
#    5/10/20  5/11/20  5/12/20  5/13/20
# ...

# %%
pd_raw_US=pd_raw_US.drop(['UID', 'iso2', 'iso3', 'code3', 'Country_Region','FIPS', 'Admin2',  'Lat', 'Long_', 'Combined_Key'],axis=1)
pd_data_base_US=pd_raw_US.rename(columns={'Province_State':'state'}).copy()

# %%
pd_relational_model_US=pd_data_base_US.set_index(['state']) \
                                .T                              \
                                .stack()             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model_US['country']='US'
pd_relational_model_US['date']=[datetime.strptime( each,"%m/%d/%y") for each in pd_relational_model_US.date] # convert to datetime
pd_relational_model_US.head()
# Out:
#         date                     state  confirmed country
# 0 2020-01-22            American Samoa          0      US
# 1 2020-01-22                      Guam          0      US
# 2 2020-01-22  Northern Mariana Islands          0      US
# 3 2020-01-22               Puerto Rico          0      US
# 4 2020-01-22            Virgin Islands          0      US

# %%
pd_relational_model_all=pd_relational_model[pd_relational_model['country']!='US'].reset_index(drop=True)

# %%
pd_relational_model_all=pd.concat([pd_relational_model_all,pd_relational_model_US],ignore_index=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
pd_relational_model_all.to_csv('../data/processed/20200513_COVID_relational_confirmed.csv',sep=';',index=False)

# %%
print(pd_relational_model_all[pd_relational_model_all['country']=='Germany'])
# Out:
#        confirmed  country       date state
# 145            0  Germany 2020-01-22    no
# 411            0  Germany 2020-01-23    no
# 677            0  Germany 2020-01-24    no
# 943            0  Germany 2020-01-25    no
# 1209           0  Germany 2020-01-26    no
# ...          ...      ...        ...   ...
# 28873     171324  Germany 2020-05-09    no
# 29139     171879  Germany 2020-05-10    no
# 29405     172576  Germany 2020-05-11    no
# 29671     173171  Germany 2020-05-12    no
# 29937     174098  Germany 2020-05-13    no
#
# [113 rows x 4 columns]
